# %% [markdown]
# # DEEP LEARNING
#
# ## TUẦN 3: NUMPY - PANDAS - MATPLOTLIB

# %%
import pandas as pd

pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# -----
# Series
#
# Pandas Series là một mảng một chiều (one-dimensional array) có chỉ mục (index).
#
# Series có thể được khởi tạo từ một danh sách (list) hoặc một mảng (array) như sau:
#
# Tạo Series từ list

# %%
data_pd = pd.Series([0.5,0.3,1.0,2.5])
data_pd
# Out:
# 0    0.5
# 1    0.3
# 2    1.0
# 3    2.5
# dtype: float64

# %% [markdown]
# tạo series từ numpy array

# %%
import numpy as np
numpy_arr = np.arange(5)
data_pd = pd.Series(numpy_arr)
data_pd
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
data_pd[-1] # khong co index -1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_pd[-1] # khong co index -1
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: -1

# %% [markdown]
# letter indexing

# %%
# Chỉ số nguyên khó dùng, thử đổi sang chữ cái

data_pd = pd.Series([1.25,2.0,0.75,1])
index=["a","b","c","d"]
data_pd
# Out:
# 0    1.25
# 1    2.00
# 2    0.75
# 3    1.00
# dtype: float64

# %%
data_pd["b"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data_pd["b"]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'b'

# %%
data_pd[-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data_pd[-1]
#       2 data_pd["b"]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: -1

# %% [markdown]
# BTVN 01: giai thich ^^^

# %% [markdown]
# combined indexing

# %%
index=["a","b","c","d",3]
data_pd = pd.Series(numpy_arr,index=index)
data_pd
# Out:
# a    0
# b    1
# c    2
# d    3
# 3    4
# dtype: int64

# %%
data_pd["a"]
# Out:
# 0

# %%
data_pd[3]
# Out:
# 4

# %% [markdown]
# pandas and dict

# %%
# Hệ thống chỉ mục của pandas có cấu trúc tương tự dictionary
# => việc tạo 1 đối tượng pandas từ dictionary là điều hoàn toàn dễ hiểu
some_pupulation_dict= {'Sài Gòn' : 59,
                       'Đồng Nai' : 60,
                       'Bình Thuận' : 86,
                       'Hà Nội' : 29 }
data_pd = pd.Series(some_pupulation_dict)
data_pd['Sài Gòn']
# Out:
# 59

# %%
#pd cũng hỗ trợ slising
# lưu ý : slising theo label là "bao gồm cả điểm kết thúc"
data_pd['Đồng Nai':'Hà Nội']
# Out:
# Đồng Nai      60
# Bình Thuận    86
# Hà Nội        29
# dtype: int64

# %% [markdown]
# Pandas và scala

# %%
# dữ liệu có thể là 1 giá trị vô hướng (scalar)
# và giá trị này sẽ được lặp lại để điền vào toàn bộ index chỉ định
data_pd = pd.Series(5, index=[2,3,8])
data_pd
# Out:
# 2    5
# 3    5
# 8    5
# dtype: int64

# %% [markdown]
# ---
# DataFrame tương tự mảng 2 chiều, với index hàng và tên cột linh hoạt; về bản chất là tập hợp các Series được căn chỉnh theo index.

# %% [markdown]
# tạo dataframe với 2 dict

# %%
#tạo dataframe với 2 dict
some_pupulation_dict = {'Sài Gòn' : 59,
                        'Đồng Nai' : 60,
                        'Bình Thuận' : 86,
                        'Hà Nội' : 29}    

some_area_dict = {'Sài Gòn' : 51,
                  'Đồng Nai' : 600,
                  'Bình Thuận' : 8686,
                  'Hà Nội' : 33,
                  'Vũng Tàu' : 72}
state = pd.DataFrame({'Population': some_pupulation_dict,
                      'Area': some_area_dict})
state
# Out:
#             Population  Area
# Sài Gòn           59.0    51
# Đồng Nai          60.0   600
# Bình Thuận        86.0  8686
# Hà Nội            29.0    33
# Vũng Tàu           NaN    72

# %% [markdown]
# indexing

# %%
state['Sài Gòn' : 'Hà Nội']
# Out:
#             Population  Area
# Sài Gòn           59.0    51
# Đồng Nai          60.0   600
# Bình Thuận        86.0  8686
# Hà Nội            29.0    33

# %%
state['Sài Gòn' : 'Hà Nội']["Population"]
# Out:
# Sài Gòn       59.0
# Đồng Nai      60.0
# Bình Thuận    86.0
# Hà Nội        29.0
# Name: Population, dtype: float64

# %%
state['Sài Gòn' : 'Hà Nội']["Population"]["Area"] # cot area da bi xoa
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 state['Sài Gòn' : 'Hà Nội']["Population"]["Area"]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File /Volumes/ExternalSSD/users/fubuki/.conda/envs/cvenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'Area'

# %%
state["Area"]
# Out:
# Sài Gòn         51
# Đồng Nai       600
# Bình Thuận    8686
# Hà Nội          33
# Vũng Tàu        72
# Name: Area, dtype: int64

# %%
state.index
# Out:
# Index(['Sài Gòn', 'Đồng Nai', 'Bình Thuận', 'Hà Nội', 'Vũng Tàu'], dtype='object')

# %%
state.index[-1]
# Out:
# 'Vũng Tàu'

# %%
state.columns
# Out:
# Index(['Population', 'Area'], dtype='object')

# %%
state.columns[0:1]
# Out:
# Index(['Population'], dtype='object')

# %% [markdown]
# êeeeeeeeeeeeee

# %%
import pandas as pd
data = pd.Series([0.75,0.5,1.0,2.0], index=['a','b','c','d'])
data
# Out:
# a    0.75
# b    0.50
# c    1.00
# d    2.00
# dtype: float64

# %%
data['a':'c']
# Out:
# a    0.75
# b    0.50
# c    1.00
# dtype: float64

# %%
data[0:2]
# Out:
# a    0.75
# b    0.50
# dtype: float64

# %% [markdown]
# add values

# %%
data['e'] = 10
data
# Out:
# a     0.75
# b     0.50
# c     1.00
# d     2.00
# e    10.00
# dtype: float64

# %% [markdown]
# in

# %%
'f' in data
# Out:
# False

# %% [markdown]
# chia khoa

# %%
data.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %% [markdown]
# items

# %%
list(data.items())
# Out:
# [('a', 0.75), ('b', 0.5), ('c', 1.0), ('d', 2.0), ('e', 10.0)]

# %%
data.values
# Out:
# array([ 0.75,  0.5 ,  1.  ,  2.  , 10.  ])

# %% [markdown]
# masking

# %%
data[(data > 0.5) & (data < 10)]
# Out:
# a    0.75
# c    1.00
# d    2.00
# dtype: float64

# %% [markdown]
# fancy indexing
